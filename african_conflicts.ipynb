# %%
import pandas as pd
import os
import numpy as np
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pickle

# %%
print(os.listdir("../ACLED"))
# Out:
# ['.git', '.gitattributes', '.ipynb_checkpoints', 'african_conflicts.csv', 'african_conflicts.ipynb', 'Analysis_app.py', 'data.pkl', 'LICENSE', 'README.md', 'requirements.txt']

# %%
df = pd.read_csv('../ACLED/african_conflicts.csv', encoding = 'latin1', low_memory = False)

# %%
## Reducing the dataset

# %%
df.shape
# Out:
# (165808, 28)

# %%
df.head()
# Out:
#                              ACTOR1  ACTOR1_ID  \
# 0  Police Forces of Algeria (1999-)        NaN
# 1                 Rioters (Algeria)        NaN
# 2              Protesters (Algeria)        NaN
# 3                 Rioters (Algeria)        NaN
# 4                 Rioters (Algeria)        NaN
#
#                              ACTOR2  ACTOR2_ID ACTOR_DYAD_ID      ADMIN1  \
# 0               Civilians (Algeria)        NaN           NaN  Tizi Ouzou
# 1  Police Forces of Algeria (1999-)        NaN           NaN  Tizi Ouzou
# 2                               NaN        NaN           NaN      Bejaia
# 3  Police Forces of Algeria (1999-)        NaN           NaN      Bejaia
# 4  Police Forces of Algeria (1999-)        NaN           NaN  Tizi Ouzou
#
#         ADMIN2 ADMIN3                   ALLY_ACTOR_1  \
# 0  Beni-Douala    NaN                            NaN
# 1   Tizi Ouzou    NaN  Berber Ethnic Group (Algeria)
# 2      Amizour    NaN             Students (Algeria)
# ...

# %%
df.tail()
# Out:
#                                                    ACTOR1  ACTOR1_ID  \
# 165803  ZANU-PF: Zimbabwe African National Union-Patri...     3929.0
# 165804                  Police Forces of Zimbabwe (1987-)     3050.0
# 165805  ZANU-PF: Zimbabwe African National Union-Patri...     3929.0
# 165806  ZNLWVA: Zimbabwe National Liberation War Veter...     3930.0
# 165807                              Protesters (Zimbabwe)     3163.0
#
#                       ACTOR2  ACTOR2_ID ACTOR_DYAD_ID            ADMIN1  \
# 165803  Civilians (Zimbabwe)      685.0      685-3929            Harare
# 165804  Civilians (Zimbabwe)      685.0      685-3050  Mashonaland West
# 165805  Civilians (Zimbabwe)      685.0      685-3929  Mashonaland East
# 165806  Civilians (Zimbabwe)      685.0      685-3930          Masvingo
# 165807                   NaN        0.0        0-3163  Mashonaland East
#
#           ADMIN2               ADMIN3  \
# 165803    Harare  Harare City Council
# ...

# %%
df.dtypes
# Out:
# ACTOR1               object
# ACTOR1_ID           float64
# ACTOR2               object
# ACTOR2_ID           float64
# ACTOR_DYAD_ID        object
# ADMIN1               object
# ADMIN2               object
# ADMIN3               object
# ALLY_ACTOR_1         object
# ALLY_ACTOR_2         object
# COUNTRY              object
# EVENT_DATE           object
# EVENT_ID_CNTY        object
# EVENT_ID_NO_CNTY    float64
# EVENT_TYPE           object
# FATALITIES            int64
# GEO_PRECISION         int64
# GWNO                  int64
# INTER1                int64
# INTER2                int64
# INTERACTION           int64
# LATITUDE             object
# LOCATION             object
# LONGITUDE            object
# NOTES                object
# SOURCE               object
# TIME_PRECISION        int64
# YEAR                  int64
# dtype: object

# %%
df['EVENT_DATE'] = pd.to_datetime(df['EVENT_DATE'], format ='%d/%m/%Y')

# %%
print(df.isnull().sum())
# Out:
# ACTOR1                   0
# ACTOR1_ID            25061
# ACTOR2               43553
# ACTOR2_ID            25061
# ACTOR_DYAD_ID        25061
# ADMIN1                   0
# ADMIN2                 132
# ADMIN3               78875
# ALLY_ACTOR_1        137664
# ALLY_ACTOR_2        146157
# COUNTRY                  0
# EVENT_DATE               0
# EVENT_ID_CNTY            0
# EVENT_ID_NO_CNTY     25061
# EVENT_TYPE               0
# FATALITIES               0
# GEO_PRECISION            0
# GWNO                     0
# INTER1                   0
# INTER2                   0
# INTERACTION              0
# LATITUDE                 0
# LOCATION                 3
# LONGITUDE                0
# NOTES                10227
# SOURCE                 173
# TIME_PRECISION           0
# YEAR                     0
# dtype: int64

# %%
COLS_KEEP = ['COUNTRY', 'YEAR', 'EVENT_TYPE', 'FATALITIES', 'LATITUDE', 'LONGITUDE', 'ADMIN1', 'ADMIN2', 'ACTOR1', 'ACTOR2', 'ACTOR1_ID', 'ACTOR2_ID', 'INTERACTION', 'ALLY_ACTOR_1','ALLY_ACTOR_2','SOURCE','NOTES']

# %%
df = df[COLS_KEEP]

# %%
df.head()
# Out:
#    COUNTRY  YEAR                  EVENT_TYPE  FATALITIES  LATITUDE LONGITUDE  \
# 0  Algeria  2001  Violence against civilians           1  36.61954   4.08282
# 1  Algeria  2001              Riots/Protests           0  36.71183   4.04591
# 2  Algeria  2001              Riots/Protests           0  36.64022   4.90131
# 3  Algeria  2001              Riots/Protests           0  36.64022   4.90131
# 4  Algeria  2001              Riots/Protests           0  36.61954   4.08282
#
#        ADMIN1       ADMIN2                            ACTOR1  \
# 0  Tizi Ouzou  Beni-Douala  Police Forces of Algeria (1999-)
# 1  Tizi Ouzou   Tizi Ouzou                 Rioters (Algeria)
# 2      Bejaia      Amizour              Protesters (Algeria)
# 3      Bejaia      Amizour                 Rioters (Algeria)
# 4  Tizi Ouzou  Beni-Douala                 Rioters (Algeria)
#
#                              ACTOR2  ACTOR1_ID  ACTOR2_ID  INTERACTION  \
# ...

# %%
df.tail()
# Out:
#          COUNTRY  YEAR                  EVENT_TYPE  FATALITIES  LATITUDE  \
# 165803  Zimbabwe  2003  Violence against civilians           0  -17.8858
# 165804  Zimbabwe  2003  Violence against civilians           0  -15.7500
# 165805  Zimbabwe  2003  Violence against civilians           0  -17.6469
# 165806  Zimbabwe  2003  Violence against civilians           0  -19.6500
# 165807  Zimbabwe  2012              Riots/Protests           0  -18.2833
#
#        LONGITUDE            ADMIN1    ADMIN2  \
# 165803   30.9919            Harare    Harare
# 165804   29.3333  Mashonaland West  Hurungwe
# 165805   31.7775  Mashonaland East   Murehwa
# 165806   31.1667          Masvingo      Gutu
# 165807   30.8666  Mashonaland East      Seke
#
#                                                    ACTOR1  \
# 165803  ZANU-PF: Zimbabwe African National Union-Patri...
# 165804                  Police Forces of Zimbabwe (1987-)
# 165805  ZANU-PF: Zimbabwe African National Union-Patri...
# ...

# %%
df.dtypes
# Out:
# COUNTRY          object
# YEAR              int64
# EVENT_TYPE       object
# FATALITIES        int64
# LATITUDE         object
# LONGITUDE        object
# ADMIN1           object
# ADMIN2           object
# ACTOR1           object
# ACTOR2           object
# ACTOR1_ID       float64
# ACTOR2_ID       float64
# INTERACTION       int64
# ALLY_ACTOR_1     object
# ALLY_ACTOR_2     object
# SOURCE           object
# NOTES            object
# dtype: object

# %%
df.EVENT_TYPE.value_counts()
# Out:
# Riots/Protests                                47224
# Violence against civilians                    45021
# Battle-No change of territory                 44005
# Strategic development                         10923
# Remote violence                               10456
# Battle-Government regains territory            2632
# Non-violent transfer of territory              2566
# Battle-Non-state actor overtakes territory     2135
# Headquarters or base established                771
# Remote Violence                                  30
# Violence Against Civilians                       21
# Battle-no change of territory                    16
# Strategic Development                             7
# Strategic development                             1
# Name: EVENT_TYPE, dtype: int64

# %%
df.describe()
# Out:
#                 YEAR     FATALITIES      ACTOR1_ID      ACTOR2_ID  \
# count  165808.000000  165808.000000  140747.000000  140747.000000
# mean     2010.760898       4.420257    2587.796692    1211.638820
# std         5.897476      76.071441    1030.065824    1242.978894
# min      1997.000000       0.000000       1.000000       0.000000
# 25%      2007.000000       0.000000    2081.000000       0.000000
# 50%      2013.000000       0.000000    3043.000000     675.000000
# 75%      2016.000000       1.000000    3288.000000    2229.000000
# max      2017.000000   25000.000000    3960.000000    3960.000000
#
#          INTERACTION
# count  165808.000000
# mean       32.001604
# std        18.284381
# min        10.000000
# 25%        15.000000
# 50%        28.000000
# 75%        47.000000
# max        88.000000

# %%
df.dtypes
# Out:
# COUNTRY          object
# YEAR              int64
# EVENT_TYPE       object
# FATALITIES        int64
# LATITUDE         object
# LONGITUDE        object
# ADMIN1           object
# ADMIN2           object
# ACTOR1           object
# ACTOR2           object
# ACTOR1_ID       float64
# ACTOR2_ID       float64
# INTERACTION       int64
# ALLY_ACTOR_1     object
# ALLY_ACTOR_2     object
# SOURCE           object
# NOTES            object
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# COUNTRY              0
# YEAR                 0
# EVENT_TYPE           0
# FATALITIES           0
# LATITUDE             0
# LONGITUDE            0
# ADMIN1               0
# ADMIN2             132
# ACTOR1               0
# ACTOR2           43553
# ACTOR1_ID        25061
# ACTOR2_ID        25061
# INTERACTION          0
# ALLY_ACTOR_1    137664
# ALLY_ACTOR_2    146157
# SOURCE             173
# NOTES            10227
# dtype: int64

# %%
with open('data.pkl', 'wb') as f:
    pickle.dump(df, f)
