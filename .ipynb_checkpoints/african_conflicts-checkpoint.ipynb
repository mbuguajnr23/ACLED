# %%
import pandas as pd
import os

# %%
print(os.listdir("../ACLED"))
# Out:
# ['.git', '.gitattributes', '.ipynb_checkpoints', 'african_conflicts.csv', 'Analysis.py', 'README.md', 'Untitled.ipynb']

# %%
df = pd.read_csv('../ACLED/african_conflicts.csv', encoding = 'latin1', low_memory = False)

# %%
##Reducing the dataset

# %%
df.shape
# Out:
# (165808, 28)

# %%
df.head()
# Out:
#                              ACTOR1  ACTOR1_ID  \
# 0  Police Forces of Algeria (1999-)        NaN
# 1                 Rioters (Algeria)        NaN
# 2              Protesters (Algeria)        NaN
# 3                 Rioters (Algeria)        NaN
# 4                 Rioters (Algeria)        NaN
#
#                              ACTOR2  ACTOR2_ID ACTOR_DYAD_ID      ADMIN1  \
# 0               Civilians (Algeria)        NaN           NaN  Tizi Ouzou
# 1  Police Forces of Algeria (1999-)        NaN           NaN  Tizi Ouzou
# 2                               NaN        NaN           NaN      Bejaia
# 3  Police Forces of Algeria (1999-)        NaN           NaN      Bejaia
# 4  Police Forces of Algeria (1999-)        NaN           NaN  Tizi Ouzou
#
#         ADMIN2 ADMIN3                   ALLY_ACTOR_1  \
# 0  Beni-Douala    NaN                            NaN
# 1   Tizi Ouzou    NaN  Berber Ethnic Group (Algeria)
# 2      Amizour    NaN             Students (Algeria)
# ...

# %%
df.tail()
# Out:
#                                                    ACTOR1  ACTOR1_ID  \
# 165803  ZANU-PF: Zimbabwe African National Union-Patri...     3929.0
# 165804                  Police Forces of Zimbabwe (1987-)     3050.0
# 165805  ZANU-PF: Zimbabwe African National Union-Patri...     3929.0
# 165806  ZNLWVA: Zimbabwe National Liberation War Veter...     3930.0
# 165807                              Protesters (Zimbabwe)     3163.0
#
#                       ACTOR2  ACTOR2_ID ACTOR_DYAD_ID            ADMIN1  \
# 165803  Civilians (Zimbabwe)      685.0      685-3929            Harare
# 165804  Civilians (Zimbabwe)      685.0      685-3050  Mashonaland West
# 165805  Civilians (Zimbabwe)      685.0      685-3929  Mashonaland East
# 165806  Civilians (Zimbabwe)      685.0      685-3930          Masvingo
# 165807                   NaN        0.0        0-3163  Mashonaland East
#
#           ADMIN2               ADMIN3  \
# 165803    Harare  Harare City Council
# ...

# %%
df.dtypes
# Out:
# ACTOR1               object
# ACTOR1_ID           float64
# ACTOR2               object
# ACTOR2_ID           float64
# ACTOR_DYAD_ID        object
# ADMIN1               object
# ADMIN2               object
# ADMIN3               object
# ALLY_ACTOR_1         object
# ALLY_ACTOR_2         object
# COUNTRY              object
# EVENT_DATE           object
# EVENT_ID_CNTY        object
# EVENT_ID_NO_CNTY    float64
# EVENT_TYPE           object
# FATALITIES            int64
# GEO_PRECISION         int64
# GWNO                  int64
# INTER1                int64
# INTER2                int64
# INTERACTION           int64
# LATITUDE             object
# LOCATION             object
# LONGITUDE            object
# NOTES                object
# SOURCE               object
# TIME_PRECISION        int64
# YEAR                  int64
# dtype: object

# %%
df['EVENT_DATE'] = pd.to_datetime(df['EVENT_DATE'], format ='%d/%m/%Y')

# %%
print(df.isnull().sum())
# Out:
# ACTOR1                   0
# ACTOR1_ID            25061
# ACTOR2               43553
# ACTOR2_ID            25061
# ACTOR_DYAD_ID        25061
# ADMIN1                   0
# ADMIN2                 132
# ADMIN3               78875
# ALLY_ACTOR_1        137664
# ALLY_ACTOR_2        146157
# COUNTRY                  0
# EVENT_DATE               0
# EVENT_ID_CNTY            0
# EVENT_ID_NO_CNTY     25061
# EVENT_TYPE               0
# FATALITIES               0
# GEO_PRECISION            0
# GWNO                     0
# INTER1                   0
# INTER2                   0
# INTERACTION              0
# LATITUDE                 0
# LOCATION                 3
# LONGITUDE                0
# NOTES                10227
# SOURCE                 173
# TIME_PRECISION           0
# YEAR                     0
# dtype: int64

# %%
COLS_KEEP = ['ACTOR1', 'ADMIN1', 'ADMIN2','ADMIN3', 'COUNTRY', 'EVENT_DATE', 'EVENT_TYPE','FATALITIES','GWNO', 'LATITUDE', 'LOCATION', 'LONGITUDE', 'SOURCE', 'YEAR']

# %%
df = df[COLS_KEEP]

# %%
COLS_KEEP = ['ACTOR1', 'ADMIN1', 'ADMIN2','ADMIN3', 'COUNTRY', 'EVENT_DATE', 'EVENT_TYPE','FATALITIES','GWNO', 'LATITUDE', 'LOCATION', 'LONGITUDE', 'SOURCE', 'YEAR']

# %%
df = df[COLS_KEEP]

# %%
df.head()
# Out:
#                              ACTOR1      ADMIN1       ADMIN2 ADMIN3  COUNTRY  \
# 0  Police Forces of Algeria (1999-)  Tizi Ouzou  Beni-Douala    NaN  Algeria
# 1                 Rioters (Algeria)  Tizi Ouzou   Tizi Ouzou    NaN  Algeria
# 2              Protesters (Algeria)      Bejaia      Amizour    NaN  Algeria
# 3                 Rioters (Algeria)      Bejaia      Amizour    NaN  Algeria
# 4                 Rioters (Algeria)  Tizi Ouzou  Beni-Douala    NaN  Algeria
#
#   EVENT_DATE                  EVENT_TYPE                  EVENT_TYPE  \
# 0 2001-04-18  Violence against civilians  Violence against civilians
# 1 2001-04-19              Riots/Protests              Riots/Protests
# 2 2001-04-20              Riots/Protests              Riots/Protests
# 3 2001-04-21              Riots/Protests              Riots/Protests
# 4 2001-04-21              Riots/Protests              Riots/Protests
#
#    FATALITIES  GWNO  LATITUDE     LOCATION LONGITUDE                   SOURCE  \
# ...

# %%
df.tail()
# Out:
#                                                    ACTOR1            ADMIN1  \
# 165803  ZANU-PF: Zimbabwe African National Union-Patri...            Harare
# 165804                  Police Forces of Zimbabwe (1987-)  Mashonaland West
# 165805  ZANU-PF: Zimbabwe African National Union-Patri...  Mashonaland East
# 165806  ZNLWVA: Zimbabwe National Liberation War Veter...          Masvingo
# 165807                              Protesters (Zimbabwe)  Mashonaland East
#
#           ADMIN2               ADMIN3   COUNTRY EVENT_DATE  \
# 165803    Harare  Harare City Council  Zimbabwe 2003-12-31
# 165804  Hurungwe         Hurungwe RDC  Zimbabwe 2003-12-31
# 165805   Murehwa          Murehwa RDC  Zimbabwe 2003-12-31
# 165806      Gutu             Gutu RDC  Zimbabwe 2003-12-31
# 165807      Seke          Manyame RDC  Zimbabwe 2012-12-31
#
#                         EVENT_TYPE                  EVENT_TYPE  FATALITIES  \
# ...

# %%
df.EVENT_TYPE.value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9596\1047950311.py in <module>
# ----> 1 df.EVENT_TYPE.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in value_counts(self, subset, normalize, sort, ascending, dropna)
#    6577             subset = self.columns.tolist()
#    6578
# -> 6579         counts = self.groupby(subset, dropna=dropna).grouper.size()
#    6580
#    6581         if sort:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7719         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720         # "Union[bool, NoDefault]"; expected "bool"
# -> 7721         return DataFrameGroupBy(
#    7722             obj=self,
#    7723             keys=by,
#
# ...

# %%
df.describe()
# Out:
#            ACTOR1_ID      ACTOR2_ID  EVENT_ID_NO_CNTY     FATALITIES  \
# count  140747.000000  140747.000000     140747.000000  165808.000000
# mean     2587.796692    1211.638820      70374.000000       4.420257
# std      1030.065824    1242.978894      40630.303506      76.071441
# min         1.000000       0.000000          1.000000       0.000000
# 25%      2081.000000       0.000000      35187.500000       0.000000
# 50%      3043.000000     675.000000      70374.000000       0.000000
# 75%      3288.000000    2229.000000     105560.500000       1.000000
# max      3960.000000    3960.000000     140747.000000   25000.000000
#
#        GEO_PRECISION           GWNO         INTER1         INTER2  \
# count  165808.000000  165808.000000  165808.000000  165808.000000
# mean        1.261061     538.296964       3.385500       3.193603
# std         0.524248      61.974200       2.033114       2.920635
# min         1.000000     404.000000       1.000000       0.000000
# ...

# %%
print()
